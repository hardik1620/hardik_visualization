# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
h = pd.read_excel("C:\\Users\\Lenovo\\OneDrive\\Documents\\CAR_DATA new.xlsx")
print(h)
# Out:
#       Unnamed: 0      name       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2       NaN      Bellevue    98004  2022            NaN
# 3              3  Thurston           NaN    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995       NaN  Port Orchard    98367  2022          TESLA
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          TESLA
# 9999        9999      King           NaN    98188  2022          TESLA
#
# [10000 rows x 6 columns]

# %%
s = h.head()
print(s)
# Out:
#    Unnamed: 0      name   country  pincode  year      cars name
# 0           0      King   Seattle    98118  2014        PORSCHE
# 1           1      King  Issaquah    98027  2023      CHEVROLET
# 2           2       NaN  Bellevue    98004  2022            NaN
# 3           3  Thurston       NaN    98503  2019            KIA
# 4           4      King  Kirkland    98034  2019  MERCEDES-BENZ

# %%
h.iloc[1:3,3:5]
# Out:
#    pincode  year
# 1    98027  2023
# 2    98004  2022

# %%
h.iloc[2:5,1:8]
# Out:
#        name   country  pincode  year      cars name
# 2       NaN  Bellevue    98004  2022            NaN
# 3  Thurston       NaN    98503  2019            KIA
# 4      King  Kirkland    98034  2019  MERCEDES-BENZ

# %%
h.tail()
# Out:
#       Unnamed: 0    name       country  pincode  year   cars name
# 9995        9995     NaN  Port Orchard    98367  2022       TESLA
# 9996        9996    King       Seattle    98106  2022  VOLKSWAGEN
# 9997        9997  Benton      Richland    99352  2019   CHEVROLET
# 9998        9998    King      Bellevue    98006  2022       TESLA
# 9999        9999    King           NaN    98188  2022       TESLA

# %%
h.dropna()
# Out:
#       Unnamed: 0    name    country  pincode  year      cars name
# 0              0    King    Seattle    98118  2014        PORSCHE
# 1              1    King   Issaquah    98027  2023      CHEVROLET
# 4              4    King   Kirkland    98034  2019  MERCEDES-BENZ
# 5              5    King  Carnation    98014  2022            KIA
# 7              7    King    Seattle    98115  2012          TESLA
# ...          ...     ...        ...      ...   ...            ...
# 9993        9993    King    Seattle    98112  2017         TOYOTA
# 9994        9994    King    Seattle    98112  2018          TESLA
# 9996        9996    King    Seattle    98106  2022     VOLKSWAGEN
# 9997        9997  Benton   Richland    99352  2019      CHEVROLET
# 9998        9998    King   Bellevue    98006  2022          TESLA
#
# [9989 rows x 6 columns]

# %%
h.isnull().sum()
# Out:
# Unnamed: 0    0
# name          4
# country       5
# pincode       0
# year          0
# cars name     4
# dtype: int64

# %%
h.isnull().sum()==0
# Out:
# Unnamed: 0     True
# name          False
# country       False
# pincode        True
# year           True
# cars name     False
# dtype: bool

# %%
h['cars name'].value_counts()
# Out:
# TESLA             4575
# NISSAN            1010
# CHEVROLET          918
# FORD               563
# BMW                516
# KIA                383
# TOYOTA             338
# VOLKSWAGEN         268
# VOLVO              194
# AUDI               194
# CHRYSLER           160
# HYUNDAI            151
# JEEP               128
# RIVIAN              88
# PORSCHE             83
# HONDA               65
# MINI                63
# POLESTAR            58
# FIAT                57
# MERCEDES-BENZ       41
# MITSUBISHI          41
# JAGUAR              27
# SMART               21
# LINCOLN             15
# SUBARU              12
# LUCID MOTORS         9
# CADILLAC             7
# LAND ROVER           3
# GENESIS              3
# not available        2
# LEXUS                1
# FISKER               1
# AZURE DYNAMICS       1
# Name: cars name, dtype: int64

# %%
h['cars name'].unique()
# Out:
# array(['PORSCHE', 'CHEVROLET', nan, 'KIA', 'MERCEDES-BENZ', 'TESLA',
#        'JEEP', 'NISSAN', 'TOYOTA', 'VOLVO', 'AUDI', 'VOLKSWAGEN', 'FORD',
#        'MITSUBISHI', 'BMW', 'CHRYSLER', 'JAGUAR', 'HYUNDAI', 'FIAT',
#        'RIVIAN', 'LINCOLN', 'MINI', 'HONDA', 'not available',
#        'LAND ROVER', 'POLESTAR', 'SUBARU', 'LUCID MOTORS', 'SMART',
#        'GENESIS', 'CADILLAC', 'LEXUS', 'FISKER', 'AZURE DYNAMICS'],
#       dtype=object)

# %%
h.notnull()
# Out:
#       Unnamed: 0   name  country  pincode  year  cars name
# 0           True   True     True     True  True       True
# 1           True   True     True     True  True       True
# 2           True  False     True     True  True      False
# 3           True   True    False     True  True       True
# 4           True   True     True     True  True       True
# ...          ...    ...      ...      ...   ...        ...
# 9995        True  False     True     True  True       True
# 9996        True   True     True     True  True       True
# 9997        True   True     True     True  True       True
# 9998        True   True     True     True  True       True
# 9999        True   True    False     True  True       True
#
# [10000 rows x 6 columns]

# %%
h.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
type(h)
# Out:
# pandas.core.frame.DataFrame

# %%
g = pd.read_excel("C:\\Users\\Lenovo\\OneDrive\\Documents\\CAR_DATA new.xlsx",usecols=['name','country','pincode'])
g
# Out:
#           name       country  pincode
# 0         King       Seattle    98118
# 1         King      Issaquah    98027
# 2          NaN      Bellevue    98004
# 3     Thurston           NaN    98503
# 4         King      Kirkland    98034
# ...        ...           ...      ...
# 9995       NaN  Port Orchard    98367
# 9996      King       Seattle    98106
# 9997    Benton      Richland    99352
# 9998      King      Bellevue    98006
# 9999      King           NaN    98188
#
# [10000 rows x 3 columns]

# %%
h.replace('NaN',np.nan)
# Out:
#       Unnamed: 0      name       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2       NaN      Bellevue    98004  2022            NaN
# 3              3  Thurston           NaN    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995       NaN  Port Orchard    98367  2022          TESLA
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          TESLA
# 9999        9999      King           NaN    98188  2022          TESLA
#
# [10000 rows x 6 columns]

# %%
#forward fill NA
h.fillna(method="ffill")
# Out:
#       Unnamed: 0      name       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2      King      Bellevue    98004  2022      CHEVROLET
# 3              3  Thurston      Bellevue    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995      King  Port Orchard    98367  2022          TESLA
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          TESLA
# 9999        9999      King      Bellevue    98188  2022          TESLA
#
# [10000 rows x 6 columns]

# %%
# backward fill NA
h.fillna(method="bfill")
# Out:
#       Unnamed: 0      name       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2  Thurston      Bellevue    98004  2022            KIA
# 3              3  Thurston      Kirkland    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995      King  Port Orchard    98367  2022          TESLA
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          TESLA
# 9999        9999      King           NaN    98188  2022          TESLA
#
# [10000 rows x 6 columns]

# %%
h.replace("TESLA","honda")
# Out:
#       Unnamed: 0      name       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2       NaN      Bellevue    98004  2022            NaN
# 3              3  Thurston           NaN    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995       NaN  Port Orchard    98367  2022          honda
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          honda
# 9999        9999      King           NaN    98188  2022          honda
#
# [10000 rows x 6 columns]

# %%
h.rename(
    columns={
        "name" : "hardik"
    }
)
# Out:
#       Unnamed: 0    hardik       country  pincode  year      cars name
# 0              0      King       Seattle    98118  2014        PORSCHE
# 1              1      King      Issaquah    98027  2023      CHEVROLET
# 2              2       NaN      Bellevue    98004  2022            NaN
# 3              3  Thurston           NaN    98503  2019            KIA
# 4              4      King      Kirkland    98034  2019  MERCEDES-BENZ
# ...          ...       ...           ...      ...   ...            ...
# 9995        9995       NaN  Port Orchard    98367  2022          TESLA
# 9996        9996      King       Seattle    98106  2022     VOLKSWAGEN
# 9997        9997    Benton      Richland    99352  2019      CHEVROLET
# 9998        9998      King      Bellevue    98006  2022          TESLA
# 9999        9999      King           NaN    98188  2022          TESLA
#
# [10000 rows x 6 columns]

# %%
h.describe()
# Out:
#         Unnamed: 0       pincode          year
# count  10000.00000  10000.000000  10000.000000
# mean    4999.50000  98164.409200   2019.320400
# std     2886.89568   2488.843774      2.923354
# min        0.00000   8033.000000   1999.000000
# 25%     2499.75000  98052.000000   2018.000000
# 50%     4999.50000  98121.000000   2020.000000
# 75%     7499.25000  98368.000000   2022.000000
# max     9999.00000  99403.000000   2023.000000

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   name        9996 non-null   object
#  2   country     9995 non-null   object
#  3   pincode     10000 non-null  int64
#  4   year        10000 non-null  int64
#  5   cars name   9996 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 468.9+ KB

# %%
h.plot.box()
# Out:
# <AxesSubplot:>

# %%
h.plot()
# Out:
# <AxesSubplot:>

# %%
h.plot.area(figsize=(10,5), subplots=True)

# %%
h.groupby("pincode").mean()
# Out:
#           Unnamed: 0         year
# pincode
# 8033     2277.000000  2019.000000
# 8202     7567.000000  2014.000000
# 21157    5862.000000  2015.000000
# 21704    5699.000000  2019.000000
# 22153    1409.000000  2022.000000
# ...              ...          ...
# 99354    6267.583333  2020.000000
# 99357    3538.000000  2022.000000
# 99361    5870.000000  2018.666667
# 99362    5041.862069  2019.068966
# 99403    6087.333333  2019.333333
#
# [408 rows x 2 columns]

# %%
h.max().sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5748\3024904675.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   h.max().sum()
# 111425

# %%
h.min().sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5748\3910448120.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   h.min().sum()
# 10032
